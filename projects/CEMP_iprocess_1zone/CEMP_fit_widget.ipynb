# %% [markdown]
# # This notebook allows to fit data of CEMP-r/s stars, analysis and download results. Spectroscopic data can be uploaded.
#
# #### Source: /nfs/rpod2/csa/CEMPrs/WidgetInterface

# %% [markdown]
# # I) Upload star data

# %% [markdown]
# ### Table format:
# ### & Element name & Line & \* &\* & \* & [Element/Fe] & \* & 1-sigma error & \* & \* \
# ### Example:
# ###  & Fe & (Fe I)  & 999 & 999 & 999    & -1.53 &  9999 & 0.20 &   22 & 44 \
#
# ###  & Fe & (Fe II)  & 999 & 999 & 999    & -1.52 &  9999 & 0.10 &   22 & 44 \

# %%
#find your data table by browsing your local machine. Test file at /rpod2/csa/CEMPrs/WidgetInterface/koch_10464.abu.
# %run upload.py
_upload()

# %% [markdown]
# ## Add info about your star

# %%
star_name='koch_1111' #appears in the final plots
author='Mr. Observer'
year='2016'

# %% [markdown]
# ## Add star to database

# %%
import update_db as udb
db=udb.add_star(star=star_name, author=author, year=year)
# Out:
# Loading the star database from the file starobs_db.h5
# Plotting class initialized.
# Support class initialized.
# 31 star(s) have been found in this database
# New star created
# This is dataset number 1 for koch_1111.
# File found
# The data that is about to be saved is :
# [Fe/Fe] = -1.53, sigma = 0.2
# [Fe/Fe] = -1.52, sigma = 0.1
# [C/Fe] = 0.41, sigma = 0.15
# [Na/Fe] = 0.54, sigma = 0.06
# [Na/Fe] = 0.01, sigma = 0.12
# [Mg/Fe] = 0.49, sigma = 0.15
# [Si/Fe] = 0.58, sigma = 0.08
# [Ca/Fe] = 0.19, sigma = 0.22
# [Sc/Fe] = 0.0, sigma = 0.12
# [Ti/Fe] = 0.37, sigma = 0.27
# [Ti/Fe] = 0.09, sigma = 0.1
# [V/Fe] = -0.18, sigma = 0.15
# [Cr/Fe] = -0.28, sigma = 0.1
# [Mn/Fe] = -0.26, sigma = 0.29
# [Co/Fe] = 0.04, sigma = 0.13
# [Ni/Fe] = 0.03, sigma = 0.2
# [Zn/Fe] = 0.31, sigma = 0.03
# [Rb/Fe] = 1.29, sigma = nan
# [Sr/Fe] = 0.84, sigma = 0.05
# [Y/Fe] = 0.46, sigma = 0.14
# [Zr/Fe] = 0.3, sigma = 0.15
# [Ba/Fe] = 1.35, sigma = 0.01
# [La/Fe] = 0.92, sigma = 0.2
# ...

# %% [markdown]
# # II) Fit the data

# %%
import fit as f
f.start_fit(db,star=star_name)
# Out:
# Fit star  koch_1111
# Nan value found for element  Rb (Z= 37.0 )!!!
# XFe=  1.29 , Err= nan , Upper= 0.0
# Fit not possible. Skip element!
# ### Elements used for fit :  ['Sr', 'Y', 'Zr', 'Ba', 'La', 'Nd', 'Eu']
# Studying :  /rpod2/csa/CEMPrs/ppn_runs_local/ppn_run_0.2_1.0_0.2/
# 936 cycle numbers found in /rpod2/csa/CEMPrs/ppn_runs_local/ppn_run_0.2_1.0_0.2/
# Ranging from 0 to 935
# Calling get method in cycle mode, adding a_iso_to_plot, z.. el.. isotope.. isotope... to instance
# WARNING: decayed in _getcycle ignores isomers and will decay alpha-unstable p-rich nuclei as if they were beta+ stable.
# Initialising decay index pointers ....
# Th does not exist in this run
# U does not exist in this run
# At does not exist in this run
# Rn does not exist in this run
# Fr does not exist in this run
# Ra does not exist in this run
# Ac does not exist in this run
# Pa does not exist in this run
# Np does not exist in this run
# Pu does not exist in this run
# ...

# %% [markdown]
# ## III) Plot results

# %%
# %matplotlib nbagg
import analysis as a
reload(a)
a.results(udb,star=star_name)
# Out:
# test  True
# mkdir analysis
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# Doing :  /rpod2/csa/CEMPrs/ppn_run_Grid/ppn_run_0.2_1.0_0.2/
# 936 cycle numbers found in /rpod2/csa/CEMPrs/ppn_run_Grid/ppn_run_0.2_1.0_0.2/
# Ranging from 0 to 935
# Calling get method in cycle mode, adding a_iso_to_plot, z.. el.. isotope.. isotope... to instance
# WARNING: decayed in _getcycle ignores isomers and will decay alpha-unstable p-rich nuclei as if they were beta+ stable.
# Initialising decay index pointers ....
# Th does not exist in this run
# U does not exist in this run
# It seems unstable species He-6 wants to decay to Li-6, however this species is not in this run. This points to an inconsistency in the network build. Here we will ignore the abundance of He-6.
# It seems unstable species Li-9 wants to decay to Be-9, however this species is not in this run. This points to an inconsistency in the network build. Here we will ignore the abundance of Li-9.
# ...

# %% [markdown]
# ## IV) Download plots and tables

# %% [markdown]
# ## <a href="analysis/data.zip">Download</a>
